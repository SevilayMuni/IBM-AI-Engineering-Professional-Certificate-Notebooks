# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# <h1>Activation Functions</h1>

# %% [markdown]
# <h2>Objective</h2><ul><li> How to apply different Activation functions in Neural Network.</li></ul>

# %%
import numpy as np
import matplotlib.pyplot as plt

import torch.nn as nn
import torch

torch.manual_seed(1)

# %% [markdown]
# <h2 id="Log">Logistic Function</h2>

# %%
# Create tensor ranging from -10 to 10

z = torch.arange(-10, 10, 0.1,).view(-1, 1)

# %%
# Create sigmoid object

sig = nn.Sigmoid()

# %%
# Apply element-wise function Sigmoid with the object

yhat = sig(z)

# also you can use yhat = torch.sigmoid(z)

# %%
# Plot the result

plt.plot(z.detach().numpy(), yhat.detach().numpy())
plt.xlabel('z')
plt.ylabel('yhat')
plt.show()

# %% [markdown]
# <h2 id="Tanh">Tanh</h2>

# %%
# Create tanh object

TANH = nn.Tanh()

# %%
# Call the object and plot it

yhat = TANH(z)
# also you can use yhat = torch.tanh(z)

plt.plot(z.numpy(), yhat.numpy())
plt.show()

# %% [markdown]
# <h2 id="Relu">Relu</h2>

# %% [markdown]
# When you use sequential, you can create a Relu object:

# %%
# Create relu object via sequential and make the prediction

RELU = nn.ReLU()
yhat = RELU(z)
# also you can use yhat = torch.relu(z) for custom modules

plt.plot(z.numpy(), yhat.numpy())
plt.show()

# %% [markdown]
# <a id="ref3"></a>
# <h2> Compare Activation Functions </h2>

# %%
# Plot the results to compare the activation functions

x = torch.arange(-2, 2, 0.1).view(-1, 1)
plt.plot(x.numpy(), torch.relu(x).numpy(), label = 'ReLU')
plt.plot(x.numpy(), torch.sigmoid(x).numpy(), label = 'Sigmoid')
plt.plot(x.numpy(), torch.tanh(x).numpy(), label = 'TANH')
plt.legend()
plt.show()

# %% [markdown]
# <a id="ref4"></a>
# <h2> Practice </h2>

# %%
# Practice: Compare the activation functions again using a tensor in the range (-1, 1)

v = torch.arange(-1, 1, 0.1).view(-1, 1)
plt.plot(v.numpy(), torch.relu(v).numpy(), label = 'ReLU')
plt.plot(v.numpy(), torch.sigmoid(v).numpy(), label = 'Sigmoid')
plt.plot(v.numpy(), torch.tanh(v).numpy(), label = 'TANH')
plt.legend()
plt.show()
